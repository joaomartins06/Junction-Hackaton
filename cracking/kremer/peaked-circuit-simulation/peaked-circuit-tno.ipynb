# %%
from utils import contract_core, tno_to_tne, extract_bitstring, iter_layers
from qiskit import QuantumCircuit
import time

# %% [markdown]
# ### Load circuits

# %%
circuit = QuantumCircuit.from_qasm_file("/home/joaomartins_06/Junction-Hackaton/cracking/circuits/challenge-40_35.qasm")

# %% [markdown]
# ### Separate circuit into layers

# %%
t0 = time.perf_counter()
circuit_layers = list(iter_layers(circuit))

# %% [markdown]
# ### Start a TNO at the center of the circuit and iteratively merge and contract layers into it

# %%
tno, _ = contract_core(circuit_layers, chunk_size=2, cutoff=0.01, max_bond=16)
tno
# Out:
#     (|156-157|-158-|159-160|)/(316) -> max_bond = 4, max_links = 4, total_elems = 288, total_shapes = 208
#     (|154-155|-158-|161-162|)/(316) -> max_bond = 4, max_links = 5, total_elems = 396, total_shapes = 236
#     (|152-153|-158-|163-164|)/(316) -> max_bond = 4, max_links = 5, total_elems = 560, total_shapes = 248
#     (|150-151|-158-|165-166|)/(316) -> max_bond = 4, max_links = 6, total_elems = 948, total_shapes = 292
#     (|148-149|-158-|167-168|)/(316) -> max_bond = 8, max_links = 7, total_elems = 2140, total_shapes = 352
#     (|146-147|-158-|169-170|)/(316) -> max_bond = 8, max_links = 7, total_elems = 3164, total_shapes = 388
#     (|144-145|-158-|171-172|)/(316) -> max_bond = 8, max_links = 9, total_elems = 4500, total_shapes = 424
#     (|142-143|-158-|173-174|)/(316) -> max_bond = 12, max_links = 9, total_elems = 6332, total_shapes = 474
#     (|140-141|-158-|175-176|)/(316) -> max_bond = 8, max_links = 9, total_elems = 6832, total_shapes = 480
#     (|138-139|-158-|177-178|)/(316) -> max_bond = 8, max_links = 9, total_elems = 8616, total_shapes = 498
#     (|136-137|-158-|179-180|)/(316) -> max_bond = 8, max_links = 10, total_elems = 15704, total_shapes = 534
#     (|134-135|-158-|181-182|)/(316) -> max_bond = 8, max_links = 10, total_elems = 28312, total_shapes = 582
#     (|132-133|-158-|183-184|)/(316) -> max_bond = 8, max_links = 10, total_elems = 49368, total_shapes = 634
#     (|130-131|-158-|185-186|)/(316) -> max_bond = 8, max_links = 10, total_elems = 64040, total_shapes = 678
#     (|128-129|-158-|187-188|)/(316) -> max_bond = 8, max_links = 11, total_elems = 83520, total_shapes = 714
#     (|126-127|-158-|189-190|)/(316) -> max_bond = 8, max_links = 12, total_elems = 152368, total_shapes = 758
#     (|124-125|-158-|191-192|)/(316) -> max_bond = 8, max_links = 12, total_elems = 188160, total_shapes = 794
#     (|122-123|-158-|193-194|)/(316) -> max_bond = 8, max_links = 12, total_elems = 231544, total_shapes = 820
#     (|120-121|-158-|195-196|)/(316) -> max_bond = 8, max_links = 12, total_elems = 287344, total_shapes = 844
#     (|118-119|-158-|197-198|)/(316) -> max_bond = 12, max_links = 12, total_elems = 414976, total_shapes = 894
#     (|116-117|-158-|199-200|)/(316) -> max_bond = 16, max_links = 12, total_elems = 917760, total_shapes = 948
#     (|114-115|-158-|201-202|)/(316) -> max_bond = 16, max_links = 14, total_elems = 1990608, total_shapes = 1016
#     (|112-113|-158-|203-204|)/(316) -> max_bond = 16, max_links = 15, total_elems = 3241344, total_shapes = 1090
#     (|110-111|-158-|205-206|)/(316) -> max_bond = 16, max_links = 15, total_elems = 4669056, total_shapes = 1132
#     (|108-109|-158-|207-208|)/(316) -> max_bond = 16, max_links = 15, total_elems = 5880704, total_shapes = 1190
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 tno, _ = contract_core(circuit_layers, chunk_size=2, cutoff=0.01, max_bond=16)
#       2 tno
#
# File ~/Junction-Hackaton/cracking/kremer/peaked-circuit-simulation/utils.py:128, in contract_core(layered_circuit, chunk_size, method, max_bond, cutoff, equalize_norms, to_backend)
#     125 tno_core = tn_left.gate_upper_with_op_lazy(tno_core).gate_upper_with_op_lazy(tn_right)
#     127 # Compress the TNO
# --> 128 tno_core = tensor_network_ag_compress(
#     129     tno_core,
#     130     method=method,
#     131     cutoff=cutoff,
#     132     max_bond=max_bond,
#     133     site_tags=tno_core.site_tags,
#     134     canonize=True,
#     135     equalize_norms=equalize_norms,
#     136 )
#     138 tno_core = tno_core.squeeze()
#     139 shapes_flat = [s for t in tno_core for s in t.shape]
#
# File ~/Junction-Hackaton/.venv/lib/python3.12/site-packages/quimb/tensor/tnag/compress.py:637, in tensor_network_ag_compress(tn, max_bond, cutoff, method, site_tags, canonize, optimize, equalize_norms, inplace, **kwargs)
#     580 def tensor_network_ag_compress(
#     581     tn: TensorNetwork,
#     582     max_bond,
#    (...)    590     **kwargs,
#     591 ):
#     592     """Compress an arbitrary geometry tensor network, with potentially multiple
#     593     tensors per site.
#     594
#    (...)    635         Supplied to the chosen compression method.
#     636     """
# --> 637     return _TNAG_COMPRESS_METHODS[method](
#     638         tn,
#     639         max_bond=max_bond,
#     640         cutoff=cutoff,
#     641         site_tags=site_tags,
#     642         canonize=canonize,
#     643         optimize=optimize,
#     644         equalize_norms=equalize_norms,
#     645         inplace=inplace,
#     646         **kwargs,
#     647     )
#
# File ~/Junction-Hackaton/.venv/lib/python3.12/site-packages/quimb/tensor/tnag/compress.py:388, in tensor_network_ag_compress_local_late(tn, max_bond, cutoff, site_tags, canonize, tree_gauge_distance, canonize_distance, canonize_after_distance, mode, optimize, equalize_norms, compress_opts, inplace, **kwargs)
#     385 for st in site_tags:
#     386     tnc.contract_(st, optimize=optimize)
# --> 388 tnc.compress_all_(**compress_opts)
#     390 # XXX: do better than simply waiting til the end to equalize norms
#     391 if equalize_norms is True:
#
# File ~/Junction-Hackaton/.venv/lib/python3.12/site-packages/quimb/tensor/tensor_core.py:6408, in TensorNetwork.compress_all(self, max_bond, cutoff, canonize, tree_gauge_distance, canonize_distance, canonize_after_distance, mode, inplace, **compress_opts)
#    6404                 tid1, tid2 = tn.ind_map[ix]
#    6405             except (ValueError, KeyError):
#    6406                 # not a bond, or index already compressed away
#    6407                 continue
# -> 6408             tn._compress_between_tids(
#    6409                 tid1,
#    6410                 tid2,
#    6411                 max_bond=max_bond,
#
# File ~/Junction-Hackaton/.venv/lib/python3.12/site-packages/quimb/tensor/tensor_core.py:6242, in TensorNetwork._compress_between_tids(self, tid1, tid2, max_bond, cutoff, absorb, canonize_distance, canonize_opts, canonize_after_distance, canonize_after_opts, mode, equalize_norms, gauges, gauge_smudge, callback, **compress_opts)
#    6238
#    6239         if mode == "basic":
#    6240             tensor_compress_bond(ta, tb, **compress_opts)
#    6241         elif mode == "virtual-tree":
# -> 6242             self._compress_between_virtual_tree_tids(
#    6243                 tid1, tid2, **compress_opts
#    6244             )
#    6245         elif mode == "full-bond":
#
# File ~/Junction-Hackaton/.venv/lib/python3.12/site-packages/quimb/tensor/tensor_core.py:5977, in TensorNetwork._compress_between_virtual_tree_tids(self, tidl, tidr, max_bond, cutoff, r, absorb, include, exclude, span_opts, **compress_opts)
#    5973         # compute the output gauges associated with the tree
#    5974         Rl, Rr = self._compute_tree_gauges(tree, [(tidl, bix), (tidr, bix)])
#    5975
#    5976         # compute the oblique projectors from the reduced factors
# -> 5977         Pl, Pr = compute_oblique_projectors(Rl, Rr.T, **compress_opts)
#    5978
#    5979         # absorb the projectors into the tensors to perform the compression
#    5980         tl.gate_(Pl.T, bix)
#
# File ~/Junction-Hackaton/.venv/lib/python3.12/site-packages/quimb/tensor/decomp.py:3142, in compute_oblique_projectors(Rl, Rr, max_bond, cutoff, absorb, cutoff_mode, method, **compress_opts)
#    3139 absorb = _ABSORB_MAP[absorb]
#    3140 cutoff_mode = _CUTOFF_MODE_MAP[cutoff_mode]
# -> 3142 Ut, st, VHt = array_split(
#    3143     Rl @ Rr,
#    3144     max_bond=max_bond,
#    3145     cutoff=cutoff,
#    3146     absorb=None,
#    3147     cutoff_mode=cutoff_mode,
#    3148     method=method,
#    3149     **compress_opts,
#    3150 )
#    3152 if absorb is None:
#    3153     Pl = Rr @ rddiv(dag(VHt), st)
#
# File ~/Junction-Hackaton/.venv/lib/python3.12/site-packages/quimb/tensor/decomp.py:173, in array_split(x, method, absorb, max_bond, cutoff, cutoff_mode, renorm, info, **kwargs)
#     170 if method in _DENSE_ONLY_METHODS and isinstance(x, spla.LinearOperator):
#     171     x = x.to_dense()
# --> 173 return _SPLIT_FNS[method](x, **split_opts, **kwargs)
#
# File ~/Junction-Hackaton/.venv/lib/python3.12/site-packages/autoray/autoray.py:1108, in Composed.__call__(self, like, *args, **kwargs)
#    1106 # `get_lib_fn` will call `make_function` if the function doesn't exist
#    1107 fn = get_lib_fn(backend, self._name)
# -> 1108 return fn(*args, **kwargs)
#
# File ~/Junction-Hackaton/.venv/lib/python3.12/site-packages/quimb/tensor/decomp.py:814, in svd_truncated(x, cutoff, cutoff_mode, max_bond, absorb, renorm, info)
#     811 cutoff_mode = _CUTOFF_MODE_MAP[cutoff_mode]
#     813 xp = get_namespace(x)
# --> 814 U, s, VH = xp.linalg.svd(x)
#     815 return _trim_and_renorm_svd_result(
#     816     U,
#     817     s,
#    (...)    825     xp=xp,
#     826 )
#
# File ~/Junction-Hackaton/.venv/lib/python3.12/site-packages/autoray/autoray.py:1329, in svd_not_full_matrices_wrapper.<locals>.default_not_full_matrices(*args, **kwargs)
#    1326 @functools.wraps(fn)
#    1327 def default_not_full_matrices(*args, **kwargs):
#    1328     kwargs.setdefault("full_matrices", False)
# -> 1329     return fn(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Apply the TNO to the |0> state

# %%
tne = tno_to_tne(tno, max_bond=8, cutoff=0.01)
# Out:
# max_bond = 3, max_links = 4

# %% [markdown]
# ### Extract the bitstring with single-bit marginals

# %%
pred_bitstring, qubit_marginals = extract_bitstring(tne)
# Out:
# /home/ubuntu/.venv/lib/python3.11/site-packages/quimb/tensor/tensor_core.py:8590: UserWarning: The contraction tree is not a compressed one, this may be very inefficient.
#   warnings.warn(

# %%
print(time.perf_counter() - t0)
# Out:
# 37.664408788084984
